# %%
def studyPlanner():
    subjs=[]
    topics=[]
    for i in range(0,4):
        subjs.append(input("Enter a subject: "))
        topics.append(input("Enter a topic in that subject: "))
    return subjs,topics

def displayAll(s,t):
    print("All subjects and topics:")
    for i in range(0,4):
        print(f"{s[i]}: {t[i]}")

def search(s,t):
    find=input("What do you want to look for?: ")
    for i in range(0,4):
        if find == s[i]:
            return True
        elif find == t[i]:
            return True

def remove(s,t):
    rem=input("What is the name of the subject/topic you want to remove: ")
    for i in range(0,4):
        if rem==s[i]:
            s[i]="None"
        elif rem==t[i]:
            t[i]="None"
    
def menu():
    s,t=studyPlanner()
    while True:
        print("\n----- Study Planner -----")
        print('''1. Enter subjects \n2. Display subjects and topics
3. Search for subject/topic\n4. Remove subject/topic\n5. Exit''')
        ch=int(input("Enter your choice: "))
        if ch==1:
            s,t=subjectPlaner()
        elif ch==2:
            displayAll(s,t)
        elif ch==3:
            isIn=search(s,t)
            if isIn==True:
                print("In study plan")
            else:
                print("Not in study plan")
        elif ch==4:
            remove(s,t)
        elif ch==5:
            break
menu()
# Out:
# ----- Study Planner -----
# 1. Enter subjects
# 2. Display subjects and topics
# 3. Search for subject/topic
# 4. Remove subject/topic
# 5. Exit
# All subjects and topics:
# Maths: Calculus
# Chemistry: Moles
# Physics: waves
# Geography: longshore drift
#
# ----- Study Planner -----
# 1. Enter subjects
# 2. Display subjects and topics
# 3. Search for subject/topic
# 4. Remove subject/topic
# 5. Exit
# In study plan
#
# ----- Study Planner -----
# 1. Enter subjects
# 2. Display subjects and topics
# 3. Search for subject/topic
# 4. Remove subject/topic
# 5. Exit
#
# ----- Study Planner -----
# 1. Enter subjects
# 2. Display subjects and topics
# 3. Search for subject/topic
# 4. Remove subject/topic
# 5. Exit
# All subjects and topics:
# None: Calculus
# Chemistry: Moles
# Physics: waves
# Geography: longshore drift
#
# ----- Study Planner -----
# 1. Enter subjects
# 2. Display subjects and topics
# 3. Search for subject/topic
# 4. Remove subject/topic
# 5. Exit

# %%
def newNotes(cat):
    chcat= input("1. Materials\n2. Processes\n3. Safty\nEnter Name of catagory: ")
    note= input("Enter the note: ")
    cat[chcat].append(note)
    return cat

def display(cat):
    chcat= input("1. Materials\n2. Processes\n3. Safty\nName of catagory: ")
    lis=cat[chcat]
    print(f"\n{chcat} Notes:\n")
    for note in lis:
        print(f"- {note}")
        
    
    
def menu():
    mat=[]
    pro=[]
    saf=[]
    cat={"Materials": mat, "Processes": pro, "Safty": saf}
    while True:
        print("\n----- Note Organiser -----")
        print('''1. Add new notes \n2. Display all notes in a catagory
3. Delete a catagory/topic\n4. Display all catagories\n5. Exit''')
        ch=int(input("Enter your choice: "))
        if ch==1:
            cat=newNotes(cat)
        elif ch==2:
            display(cat)
        elif ch==3:
            del_cat = input('''Enter the name of the category to delete (Materials, Processes, Safety): ''')
            if del_cat in cat:
                cat[del_cat] = []  
                print(f"{del_cat} category has been deleted.")
            else:
                print("Category not found.")
        elif ch==4:
            print("\nCategories available:")
            for category in cat:
                print(f"- {category}")
        elif ch==5:
            break
menu()
# Out:
# ----- Note Organiser -----
# 1. Add new notes
# 2. Display all notes in a catagory
# 3. Delete a catagory/topic
# 4. Display all catagories
# 5. Exit
#
# ----- Note Organiser -----
# 1. Add new notes
# 2. Display all notes in a catagory
# 3. Delete a catagory/topic
# 4. Display all catagories
# 5. Exit
#
# Categories available:
# - Materials
# - Processes
# - Safty
#
# ----- Note Organiser -----
# 1. Add new notes
# 2. Display all notes in a catagory
# 3. Delete a catagory/topic
# 4. Display all catagories
# 5. Exit
# Processes category has been deleted.
#
# ----- Note Organiser -----
# 1. Add new notes
# 2. Display all notes in a catagory
# 3. Delete a catagory/topic
# 4. Display all catagories
# 5. Exit
#
# Categories available:
# - Materials
# - Processes
# - Safty
#
# ----- Note Organiser -----
# 1. Add new notes
# 2. Display all notes in a catagory
# 3. Delete a catagory/topic
# 4. Display all catagories
# 5. Exit
